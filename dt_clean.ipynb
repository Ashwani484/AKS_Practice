# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date

df=pd.read_csv("D:\\NSE\\latest\\NFL1.csv")
df
# Out:
# C:\Users\Ashwani-Suyanka\AppData\Local\Temp\ipykernel_9472\2540321744.py:6: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("D:\\NSE\\latest\\NFL1.csv")
#        Unnamed: 0        Date      GameID  Drive  qtr  down   time  TimeUnder
# 0               0  2009-09-10  2009091000      1    1   NaN  15:00         15  \
# 1               1  2009-09-10  2009091000      1    1   1.0  14:53         15
# 2               2  2009-09-10  2009091000      1    1   2.0  14:16         15
# 3               3  2009-09-10  2009091000      1    1   3.0  13:35         14
# 4               4  2009-09-10  2009091000      1    1   4.0  13:27         14
# ...           ...         ...         ...    ...  ...   ...    ...        ...
# 49995       49995  2010-09-20  2010092000      7    2   1.0  12:19         13
# 49996       49996  2010-09-20  2010092000      7    2   2.0  12:14         13
# ...

# %%
blank=pd.DataFrame(df[df.columns[df.isna().any()]])
blank.isna().sum()

obj=blank[blank.columns[blank.dtypes==object]]
print(obj.columns)
#obj['SideofField'].isnull().sum()
inte=blank[blank.columns[blank.dtypes==float]]
inte['PlayTimeDiff'].describe()
# Out:
# Index(['time', 'SideofField', 'posteam', 'DefensiveTeam', 'ExPointResult',
#        'TwoPointConv', 'PuntResult', 'Passer', 'Passer_ID', 'PassOutcome',
#        'PassLength', 'PassLocation', 'Interceptor', 'Rusher', 'Rusher_ID',
#        'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID', 'ReturnResult',
#        'Returner', 'BlockingPlayer', 'Tackler1', 'Tackler2', 'FieldGoalResult',
#        'RecFumbTeam', 'RecFumbPlayer', 'ChalReplayResult', 'PenalizedTeam',
#        'PenaltyType', 'PenalizedPlayer', 'Timeout_Team'],
#       dtype='object')
# count    49932.000000
# mean        20.851278
# std         16.920352
# min          0.000000
# 25%          5.000000
# 50%         17.000000
# 75%         38.000000
# max        234.000000
# Name: PlayTimeDiff, dtype: float64
